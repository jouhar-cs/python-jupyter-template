# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.
import matplotlib.pyplot as plt

# Data for plots
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
scatter_x = [1, 2, 3, 4, 5]
scatter_y = [2, 4, 6, 8, 10]
pie_labels = ['Python', 'Java', 'C++', 'JavaScript']
pie_sizes = [40, 25, 20, 15]

# Create the 2x2 subplot layout
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Line chart
axs[0, 0].plot(x, y, marker='o')
axs[0, 0].set_title('Line Chart')
axs[0, 0].set_xlabel('X-axis')
axs[0, 0].set_ylabel('Y-axis')

# Bar chart
axs[0, 1].bar(categories, values, color=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'])
axs[0, 1].set_title('Bar Chart')
axs[0, 1].set_xlabel('Categories')
axs
# Out:
# array([[<Axes: title={'center': 'Line Chart'}, xlabel='X-axis', ylabel='Y-axis'>,
#         <Axes: title={'center': 'Bar Chart'}, xlabel='Categories'>],
#        [<Axes: >, <Axes: >]], dtype=object)
